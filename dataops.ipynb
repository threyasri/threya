# %% [markdown]
# <a href="https://colab.research.google.com/github/threyasri/threya/blob/main/dataops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# updated code
import pandas as pd

# %%
file_path = '/content/drive/MyDrive/dataops/dataops.xlsx'
df = pd.read_excel(file_path, engine='openpyxl')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['Total'] = df[['math score','reading score','writing score']].sum(axis=1)
df['Maximum'] = df[['math score','reading score','writing score']].max(axis=1)
df['Minimum'] = df[['math score','reading score','writing score']].min(axis=1)
df['Average'] = df[['math score','reading score','writing score']].mean(axis=1)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  Total
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  Total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#    Maximum
# 0       74
# 1       90
# 2       95
# 3       57
# 4       78

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  Total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#    Maximum  Minimum    Average
# 0       74       72  72.666667
# 1       90       69  82.333333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   Total                        1000 non-null   int64
#  9   Maximum                      1000 non-null   int64
#  10  Minimum                      1000 non-null   int64
#  11  Average                      1000 non-null   float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score        Total      Maximum  \
# count  1000.00000    1000.000000    1000.000000  1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000    72.396000
# std      15.16308      14.600192      15.195657    42.771978    14.240083
# min       0.00000      17.000000      10.000000    27.000000    17.000000
# 25%      57.00000      59.000000      57.750000   175.000000    62.000000
# 50%      66.00000      70.000000      69.000000   205.000000    73.000000
# 75%      77.00000      79.000000      79.000000   233.000000    82.000000
# max     100.00000     100.000000     100.000000   300.000000   100.000000
#
#            Minimum      Average
# count  1000.000000  1000.000000
# mean     62.607000    67.770667
# std      14.676374    14.257326
# min       0.000000     9.000000
# 25%      53.000000    58.333333
# 50%      63.000000    68.333333
# 75%      73.000000    77.666667
# max     100.000000   100.000000

# %%
import matplotlib.pyplot as plt
df['Total'].plot(kind='hist', bins=10, color='pink', edgecolor='black', title='Histogram of Total Marks')
plt.xlabel('Total Marks')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4008db59c937> in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
# ----> 2 df['Total'].plot(kind='hist', bins=10, color='pink', edgecolor='black', title='Histogram of Total Marks')
#       3 plt.xlabel('Total Marks')
#       4 plt.ylabel('Frequency')
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
